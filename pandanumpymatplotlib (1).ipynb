# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
df=pd.read_csv("C:\employees.csv")
df
# Out:
#    EmpID    Name  Age  Gender Department   salary  Experience
# 0    101    Ravi   25    Male         IT  30000.0           2
# 1    102   Sneha   30  Female         HR  40000.0           5
# 2    103   Arjun   35    Male         IT  50000.0           8
# 3    104   Priya   28  Female    Finance  45000.0           4
# 4    105   Kiran   40    Male         HR  55000.0          10
# 5    106  Anjali   26  Female         IT      NaN           3

# %%
df.head()
# Out:
#    EmpID   Name  Age  Gender Department   salary  Experience
# 0    101   Ravi   25    Male         IT  30000.0           2
# 1    102  Sneha   30  Female         HR  40000.0           5
# 2    103  Arjun   35    Male         IT  50000.0           8
# 3    104  Priya   28  Female    Finance  45000.0           4
# 4    105  Kiran   40    Male         HR  55000.0          10

# %%
df.tail()
# Out:
#    EmpID    Name  Age  Gender Department   salary  Experience
# 1    102   Sneha   30  Female         HR  40000.0           5
# 2    103   Arjun   35    Male         IT  50000.0           8
# 3    104   Priya   28  Female    Finance  45000.0           4
# 4    105   Kiran   40    Male         HR  55000.0          10
# 5    106  Anjali   26  Female         IT      NaN           3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       6 non-null      int64
#  1   Name        6 non-null      object
#  2   Age         6 non-null      int64
#  3   Gender      6 non-null      object
#  4   Department  6 non-null      object
#  5   salary      5 non-null      float64
#  6   Experience  6 non-null      int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 468.0+ bytes

# %%
df.describe() # show values like,mean,median,mode
# Out:
#             EmpID        Age        salary  Experience
# count    6.000000   6.000000      5.000000    6.000000
# mean   103.500000  30.666667  44000.000000    5.333333
# std      1.870829   5.785038   9617.692031    3.076795
# min    101.000000  25.000000  30000.000000    2.000000
# 25%    102.250000  26.500000  40000.000000    3.250000
# 50%    103.500000  29.000000  45000.000000    4.500000
# 75%    104.750000  33.750000  50000.000000    7.250000
# max    106.000000  40.000000  55000.000000   10.000000

# %%
df.shape # rettttrive shape of table as rows and column
# Out:
# (6, 7)

# %%
df.columns #retrive colum names
# Out:
# Index(['EmpID', 'Name', 'Age', 'Gender', 'Department', 'salary', 'Experience'], dtype='object')

# %%
df["Name"]#retriving colums of name
# Out:
# 0      Ravi
# 1     Sneha
# 2     Arjun
# 3     Priya
# 4     Kiran
# 5    Anjali
# Name: Name, dtype: object

# %%
df["salary"] #retriving colums of salary
# Out:
# 0    30000.0
# 1    40000.0
# 2    50000.0
# 3    45000.0
# 4    55000.0
# 5        NaN
# Name: salary, dtype: float64

# %%
df[["Name","salary"]] # retriving colums of name,salary at a time
# Out:
#      Name   salary
# 0    Ravi  30000.0
# 1   Sneha  40000.0
# 2   Arjun  50000.0
# 3   Priya  45000.0
# 4   Kiran  55000.0
# 5  Anjali      NaN

# %%
df.loc[5]# finding null values row wise
# Out:
# EmpID            106
# Name          Anjali
# Age               26
# Gender        Female
# Department        IT
# salary           NaN
# Experience         3
# Name: 5, dtype: object

# %%
df.isnull()
# Out:
#    EmpID   Name    Age  Gender  Department  salary  Experience
# 0  False  False  False   False       False   False       False
# 1  False  False  False   False       False   False       False
# 2  False  False  False   False       False   False       False
# 3  False  False  False   False       False   False       False
# 4  False  False  False   False       False   False       False
# 5  False  False  False   False       False    True       False

# %%
df.isnull().sum()# count of null values row wise
# Out:
# EmpID         0
# Name          0
# Age           0
# Gender        0
# Department    0
# salary        1
# Experience    0
# dtype: int64

# %%
df.fillna(0) # fill null values with 0
# Out:
#    EmpID    Name  Age  Gender Department   salary  Experience
# 0    101    Ravi   25    Male         IT  30000.0           2
# 1    102   Sneha   30  Female         HR  40000.0           5
# 2    103   Arjun   35    Male         IT  50000.0           8
# 3    104   Priya   28  Female    Finance  45000.0           4
# 4    105   Kiran   40    Male         HR  55000.0          10
# 5    106  Anjali   26  Female         IT      0.0           3

# %%
df[df["Age"]>25] #filtering based on age
# Out:
#    EmpID    Name  Age  Gender Department   salary  Experience
# 1    102   Sneha   30  Female         HR  40000.0           5
# 2    103   Arjun   35    Male         IT  50000.0           8
# 3    104   Priya   28  Female    Finance  45000.0           4
# 4    105   Kiran   40    Male         HR  55000.0          10
# 5    106  Anjali   26  Female         IT      NaN           3

# %%
df.groupby("Department").count()     # adding new column
# Out:
#             EmpID  Name  Age  Gender  salary  Experience
# Department
# Finance         1     1    1       1       1           1
# HR              2     2    2       2       2           2
# IT              3     3    3       3       2           3

# %%
df["exsalary"]=[40000,50000,60000,70000,40000,20000]
df
# Out:
#    EmpID    Name  Age  Gender Department   salary  Experience  exsalary
# 0    101    Ravi   25    Male         IT  30000.0           2     40000
# 1    102   Sneha   30  Female         HR  40000.0           5     50000
# 2    103   Arjun   35    Male         IT  50000.0           8     60000
# 3    104   Priya   28  Female    Finance  45000.0           4     70000
# 4    105   Kiran   40    Male         HR  55000.0          10     40000
# 5    106  Anjali   26  Female         IT      NaN           3     20000

# %%
df.drop("exsalary",axis=1)#delete the column
# Out:
#    EmpID    Name  Age  Gender Department   salary  Experience
# 0    101    Ravi   25    Male         IT  30000.0           2
# 1    102   Sneha   30  Female         HR  40000.0           5
# 2    103   Arjun   35    Male         IT  50000.0           8
# 3    104   Priya   28  Female    Finance  45000.0           4
# 4    105   Kiran   40    Male         HR  55000.0          10
# 5    106  Anjali   26  Female         IT      NaN           3

# %%
df.sort_values("Age")#sort by age
# Out:
#    EmpID    Name  Age  Gender Department   salary  Experience  exsalary
# 0    101    Ravi   25    Male         IT  30000.0           2     40000
# 5    106  Anjali   26  Female         IT      NaN           3     20000
# 3    104   Priya   28  Female    Finance  45000.0           4     70000
# 1    102   Sneha   30  Female         HR  40000.0           5     50000
# 2    103   Arjun   35    Male         IT  50000.0           8     60000
# 4    105   Kiran   40    Male         HR  55000.0          10     40000

# %%
df["salary"].mean()#average salary
# Out:
# 44000.0

# %%
df[df["Age"]>30]#retriving emp whos age is greater then 30
# Out:
#    EmpID   Name  Age Gender Department   salary  Experience  exsalary
# 2    103  Arjun   35   Male         IT  50000.0           8     60000
# 4    105  Kiran   40   Male         HR  55000.0          10     40000

# %%
df.groupby("Department") #group by department
df["salary"].mean()
# Out:
# 44000.0

# %%
import numpy as np
a=np.array([1,2,3,4]) #creating on dimensinal array
print(a)
# Out:
# [1 2 3 4]

# %%
b=np.array([[1,2],[3,4]])#creating two dimwnsinal array
print(b)
# Out:
# [[1 2]
#  [3 4]]

# %%
np.zeros((2,3))#creating array of 2,3 with all values as 0
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))#creating 2,3 array with all values as 1
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(0,10,2) #creating on d array with number start from zero and end at 10 and space are gap between them are 2
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0,1,4)# finding 4 values which are between 0 and 1
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
a.shape# shage of array a
# Out:
# (4,)

# %%
b.shape# shage of array b
# Out:
# (2, 2)

# %%
a.ndim#dimensions of array a
# Out:
# 1

# %%
b.ndim#dimensions of array b
# Out:
# 2

# %%
a.size#number of elements
# Out:
# 4

# %%
b.size#number of elements
# Out:
# 4

# %%
a.dtype
# Out:
# dtype('int32')

# %%
b.dtype
# Out:
# dtype('int32')

# %%
a[0]#index value
# Out:
# 1

# %%
a[3]#index value
# Out:
# 4

# %%
a[2]#index value
# Out:
# 3

# %%
a[1:3] #index vlues startr from 1 and end at 3
# Out:
# array([2, 3])

# %%
a[0:3]#index values start at 2 end at 3
# Out:
# array([1, 2, 3])

# %%
b[0,1]#0 implies row 1 implies column
# Out:
# 2

# %%
a+5 #adding a numeric value to every element of array
# Out:
# array([6, 7, 8, 9])

# %%
b+10  #adding a numeric value to every element of array
# Out:
# array([[11, 12],
#        [13, 14]])

# %%
a*2 #multiplying numeric value 2 ti every element of array a
# Out:
# array([2, 4, 6, 8])

# %%
np.sqrt(a)
# Out:
# array([1.        , 1.41421356, 1.73205081, 2.        ])

# %%
np.sqrt(b)
# Out:
# array([[1.        , 1.41421356],
#        [1.73205081, 2.        ]])

# %%
np.sum(a)
# Out:
# 10

# %%
np.sum(b)
# Out:
# 10

# %%
np.mean(a)
# Out:
# 2.5

# %%
np.mean(b)
# Out:
# 2.5

# %%
np.max(a)
# Out:
# 4

# %%
np.max(b)
# Out:
# 4

# %%
a.reshape(2,2)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.random.rand(3)
# Out:
# array([0.04601062, 0.64147591, 0.30035374])

# %%
np.random.randint(1,10,5)
# Out:
# array([4, 5, 2, 3, 3])

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-label")
plt.title("simple line plot")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[50,100,200,400]
y=[5,10,20,40]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("simple line graph")
plt.show()

# %%
import matplotlib.pyplot as plt
subjects=["maths","statistics","english"]
marks=[80,95,100]
plt.bar(subjects,marks)
plt.xlabel("subjects")
plt.ylabel("marks")
plt.title("marks bar chart")
plt.show()
